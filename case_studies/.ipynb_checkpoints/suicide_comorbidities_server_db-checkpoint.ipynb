# %% [markdown]
# ### Suicide Comorbidities (using Brown MySQL server)
#
# This script run a PubMed-Comorbidities pipeline using the following characteristics:
#
# * Main MeSH Heading: Colonic Neoplasms
# * UMLS filtering concept: "Disease or Syndrome", "Mental or Behavioral Dysfunction" or "Neoplastic Process"
# * Articles analysed: All MEDLINE 2017AA articles tagged with the  as a MeSH Heading. Note that this is equivalent to searching PubMed using [MH:noexp]
#   Total number of articles found: 63304
# * UMLS concept filtering: Comorbidities are analysed on all other MeSH descriptors associated with the specified UMLS concepts
# * This script uses Brown MySQL databases:
#     * medline
#     * umls_meta
#     * pubmed_miner

# %%
#Optional for running Step 1. However, sometimes the concurrancy of DatabaBase creates errors. 
#If that happens, reduce the number of process or comment out the line completely. 
#The fewer the processes the longer the task. At times I've successfully used 12 workers, at others only 2
addprocs(2);

# %%
using Revise #used during development to detect changes in module - unknown behavior if using multiple processes
using PubMedMiner

# %%
#Settings
const mh = "Suicide"
const concepts = ("Disease or Syndrome", "Mental or Behavioral Dysfunction", "Neoplastic Process");

# %% [markdown]
# ## 1. Save related occurrences to database
#
# The folllowing code is designed to save to the pubmed_miner database a table containing the list of pmids and mesh descriptors that match the specified filtering criteria.

# %%
overwrite = false
@time save_semantic_occurrences(mh, concepts...; overwrite = overwrite)
# Out:
# INFO: 33806 Articles related to MH:Suicide
# INFO: ----------------------------------------
# INFO: Start all articles
# INFO: Using concept table: MESH_T047
# INFO: Using results table: suicide_mesh_t047
# INFO: Table exists and will remain unchanged
# INFO: Using concept table: MESH_T048
# INFO: Using results table: suicide_mesh_t048
# INFO: Table exists and will remain unchanged
# INFO: Using concept table: MESH_T191
# INFO: Using results table: suicide_mesh_t191
# INFO: Table doesn't exist, create
# 244.662948 seconds (5.00 M allocations: 185.202 MiB, 0.02% gc time)

# %% [markdown]
# ## 2. Retrieve results and analyze simple occurrences and co-occurrences

# %%
using FreqTables

@time occurrence_df = get_semantic_occurrences_df(mh, concepts...)
@time mesh_frequencies = freqtable(occurrence_df, :pmid, :descriptor);

info("Found ", size(occurrence_df, 1), " related descriptors")
# Out:
# INFO: Using concept table: MESH_T047
# INFO: Using results table: suicide_mesh_t047
# INFO: Using concept table: MESH_T048
# INFO: Using results table: suicide_mesh_t048
#   0.994594 seconds (1.03 M allocations: 46.199 MiB, 2.21% gc time)
# INFO: Using concept table: MESH_T191
# INFO: Using results table: suicide_mesh_t191
#   1.353433 seconds (1.19 M allocations: 176.308 MiB, 3.00% gc time)
# INFO: Found 32017 related descriptors

# %%
using PlotlyJS
using NamedArrays

# Visualize frequency 
topn = 50
mesh_counts = vec(sum(mesh_frequencies, 1))
count_perm = sortperm(mesh_counts, rev=true)
mesh_names = collect(keys(mesh_frequencies.dicts[2]))

#traces
#remove from plot for better scaling
freq_trace = PlotlyJS.bar(; x = mesh_names[count_perm[1:topn]], y= mesh_counts[count_perm[1:topn]], marker_color="orange")

data = [freq_trace]
layout = Layout(;title="$(topn)-Most Frequent MeSH ",
                 showlegend=false,
                 margin= Dict(:t=> 70, :r=> 0, :l=> 50, :b=>200),
                 xaxis_tickangle = 90,)
plot(data, layout)
# Out:
# <div id="4a97c964-8469-4424-bd10-eedc8b7719e8" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('4a97c964-8469-4424-bd10-eedc8b7719e8', [{"marker":{"color":"orange"},"y":[3663,2909,2859,1666,1165,1097,1085,1060,973,773,763,516,460,383,380,359,343,281,272,252,239,234,234,210,188,167,164,164,154,153,135,120,113,110,110,109,109,108,107,98,95,93,93,92,92,89,89,88,87,85],"type":"bar","x":["Mental Disorders","Depressive Disorder","Depression","Substance-Related Disorders","Alcoholism","Schizophrenia","Stress, Psychological","Violence","Bipolar Disorder","Depressive Disorder, Major","Psychotic Disorders","Personality Disorders","Neoplasms","Stress Disorders, Post-Traumatic","Mood Disorders","Anxiety Disorders","Chronic Disease","Neurotic Disorders","Cardiovascular Diseases","Alcoholic Intoxication","Borderline Personality Disorder","Acute Disease","Child Abuse","Epilepsy","Adjustment Disorders","Acquired Immunodeficiency Syndrome","Antisocial Personality Disorder","Occupational Diseases","Psychophysiologic Disorders","Dementia","HIV Infections","Neurocognitive Disorders","Cognition Disorders","Delusions","Paranoid Disorders","Child Abuse, Sexual","Sleep Initiation and Maintenance Disorders","Child Behavior Disorders","Sleep Wake Disorders","Feeding and Eating Disorders","Pregnancy Complications","Hallucinations","Psychoses, Substance-Induced","Burnout, Professional","Heart Diseases","Cerebrovascular Disorders","Obsessive-Compulsive Disorder","Domestic Violence","Coma","Coronary Disease"]}],
#                {"showlegend":false,"xaxis":{"tickangle":90},"margin":{"l":50,"b":200,"r":0,"t":70},"title":"50-Most Frequent MeSH "}, {showLink: false});
#
#     });
#  </script>

# %% [markdown]
# ## 3. Pair Statistics
#
# * Mutual information
# * Chi-Square
# * Co-occurrance matrix

# %%
using BCBIStats.COOccur
using StatsBase

#co-occurrance matrix - only for topp MeSH 
# min_frequency = 5 -- alternatively compute topn based on min-frequency
top_occ = mesh_frequencies.array[:, count_perm[1:topn]]
top_mesh_labels = mesh_names[count_perm[1:topn]]
top_occ_sp = sparse(top_occ)
top_coo_sp = top_occ_sp' * top_occ_sp


#Point Mutual Information
pmi_sp = BCBIStats.COOccur.pmi_mat(top_top_coo_sp)
#chi2
top_chi2= BCBIStats.COOccur.chi2_mat(top_occ, min_freq=0);

# %%
# typeof(full(top_chi2))
#Display full matrices as heatmaps
pmi_trace = heatmap(; z=full(pmi_sp), showscale=false)
chi2_trace = heatmap(; z=full(top_chi2), showscale=false)
coo_stats_plot = [plot(trace1) plot(trace2)]
# Out:
# UndefVarError: dense not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at ./loading.jl:515

# %%
using PlotlyJSFactory

p = create_chord_plot(top_coo_sp, labels = top_mesh_labels)
relayout!(p, title="Co-occurrances between top 50 MeSH terms")
JupyterPlot(p)
# Out:
# <div id="8bf16ad6-2e46-4d48-a57b-934b69ace7b5" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('8bf16ad6-2e46-4d48-a57b-934b69ace7b5', [{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":3.5903614457831323},"y":[0.0,0.01664582008275916,0.05483328968438311,0.09693742283489157,0.12533323356430426],"type":"scatter","hoverinfo":"none","x":[1.0,0.905202733768329,0.8715501818250841,0.9001512142979164,0.9921147013144779]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":3.6987951807228914},"y":[0.0,0.03302912563908228,0.10880182563462397,0.19234608460406738,0.2486898871648548],"type":"scatter","hoverinfo":"none","x":[1.0,0.9020774510873962,0.8612551329937761,0.8819510386854257,0.9685831611286311]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":5.0},"y":[0.0,0.04889154215343379,0.16105449179954662,0.2847213337170556,0.3681245526846779],"type":"scatter","hoverinfo":"none","x":[1.0,0.8969234395320334,0.84427721257611,0.8519365008041945,0.9297764858882515]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":3.4939759036144578},"y":[0.0,0.06398290984163407,0.21076723241950046,0.3726063573130455,0.4817536741017153],"type":"scatter","hoverinfo":"none","x":[1.0,0.8898219809433257,0.8208841725191904,0.8105809478464259,0.8763066800438636]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":2.3734939759036147},"y":[0.0,0.07806522882009409,0.257156047877957,0.45461515606995967,0.5877852522924731],"type":"scatter","hoverinfo":"none","x":[1.0,0.8808850695654228,0.7914449350390396,0.7585365815868734,0.8090169943749475]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":2.072289156626506},"y":[0.0,0.09091641250615395,0.2994893588438013,0.5294544022417201,0.6845471059286886],"type":"scatter","hoverinfo":"none","x":[1.0,0.8702536458294061,0.7564237744968676,0.696624172771248,0.7289686274214116]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":2.108433734939759},"y":[0.0,0.08427488592860195,0.28894246604092094,0.5417671238267268,0.7705132427757893],"type":"scatter","hoverinfo":"none","x":[1.0,0.772843248878763,0.6140339961557586,0.5575637427920475,0.6374239897486897]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":1.1204819277108433},"y":[0.0,0.09234836685178291,0.3166229720632556,0.5936680726186043,0.8443279255020151],"type":"scatter","hoverinfo":"none","x":[1.0,0.7617310557008277,0.5759350481171237,0.4861282152196069,0.5358267949789965]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":0.7951807228915663},"y":[0.0,0.0989654588634709,0.33931014467475734,0.6362065212651701,0.9048270524660196],"type":"scatter","hoverinfo":"none","x":[1.0,0.7496946100149298,0.5346672343369022,0.40875106438169173,0.42577929156507266]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":2.4698795180722892},"y":[0.0,0.1040218064697824,0.35664619361068256,0.6687116130200298,0.9510565162951535],"type":"scatter","hoverinfo":"none","x":[1.0,0.7369237337597598,0.4908813728906053,0.3266525741698849,0.30901699437494745]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":1.9397590361445782},"y":[0.0,0.10743766804845031,0.3683577190232582,0.6906707231686091,0.9822872507286886],"type":"scatter","hoverinfo":"none","x":[1.0,0.7236198312828137,0.44526799296964675,0.2411274868180877,0.18738131458572474]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":0.46987951807228917},"y":[0.0,0.1091591734218422,0.3742600231606018,0.7017375434261284,0.9980267284282716],"type":"scatter","hoverinfo":"none","x":[1.0,0.7099927130735186,0.39854644482349255,0.15352458404404856,0.06279051952931353]},{"mode":"lines","line":{"color":"rgba(0,51,181, 0.85)","shape":"spline","width":0.6746987951807228},"y":[0.0,0.09356500579015047,0.3326755761427572,0.6549550405310532,0.9980267284282716],"type":"scatter","hoverinfo":"none" ...

# %% [markdown]
# ### Association Rules
#
# * Compute using apriori algorithm (eclat version)

# %%
using ARules
using DataTables
# Out:
# WARNING: Method definition ==(Base.Nullable{S}, Base.Nullable{T}) in module Base at nullable.jl:238 overwritten in module NullableArrays at /Users/isa/.julia/v0.6/NullableArrays/src/operators.jl:99.
# WARNING: Method definition append!(NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}, NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}) in module Data at /Users/isa/.julia/v0.6/DataStreams/src/DataStreams.jl:344 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/io.jl:318.
# WARNING: Method definition describe(AbstractArray{T, N} where N where T) in module StatsBase at /Users/isa/.julia/v0.6/StatsBase/src/scalarstats.jl:559 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/abstractdatatable.jl:381.
# WARNING: Method definition ==(Base.Nullable{S}, Base.Nullable{T}) in module Base at nullable.jl:238 overwritten in module NullableArrays at /Users/isa/.julia/v0.6/NullableArrays/src/operators.jl:99.
# WARNING: Method definition ==(Base.Nullable{S}, Base.Nullable{T}) in module Base at nullable.jl:238 overwritten in module NullableArrays at /Users/isa/.julia/v0.6/NullableArrays/src/operators.jl:99.
# WARNING: Method definition append!(NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}, NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}) in module Data at /Users/isa/.julia/v0.6/DataStreams/src/DataStreams.jl:344 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/io.jl:318.
# WARNING: Method definition describe(AbstractArray{T, N} where N where T) in module StatsBase at /Users/isa/.julia/v0.6/StatsBase/src/scalarstats.jl:559 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/abstractdatatable.jl:381.
# WARNING: Method definition append!(NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}, NullableArrays.NullableArray{WeakRefStrings.WeakRefString{T}, 1}) in module Data at /Users/isa/.julia/v0.6/DataStreams/src/DataStreams.jl:344 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/io.jl:318.
# WARNING: Method definition describe(AbstractArray{T, N} where N where T) in module StatsBase at /Users/isa/.julia/v0.6/StatsBase/src/scalarstats.jl:559 overwritten in module DataTables at /Users/isa/.julia/v0.6/DataTables/src/abstractdatatable/abstractdatatable.jl:381.
# WARNING: Compat.AsyncCondition is deprecated, use Base.AsyncCondition instead.
#   likely near /Users/isa/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.AsyncCondition is deprecated, use Base.AsyncCondition instead.
#   likely near /Users/isa/.julia/v0.6/IJulia/src/kernel.jl:31

# %%
mh_occ = convert(BitArray{2}, mesh_frequencies.array)

# We don't need to remove Suicide (MH) because is not of the available UMLS types
# mh_col = mesh_frequencies.dicts[2][mh]
# mh_occ[:, mh_col] = zeros(size(mh_occ,1))

epilepsy_lkup = convert(DataStructures.OrderedDict{String,Int16}, mesh_frequencies.dicts[2]) 
@time epilepsy_rules = apriori(mh_occ, supp = 0.001, conf = 0.1, maxlen = 9)

#Pretty print of rules
epilepsy_lkup = Dict(zip(values(mesh_frequencies.dicts[2]), keys(mesh_frequencies.dicts[2])))
rules_dt= ARules.rules_to_datatable(epilepsy_rules, epilepsy_lkup, join_str = " | ");
# Out:
#   0.846432 seconds (513.53 k allocations: 59.463 MiB, 3.92% gc time)

# %%
println(head(rules_dt))
println("Found ", size(rules_dt, 1), " rules")
# Out:
# 6×5 DataTables.DataTable
# │ Row │ lhs                                  │
# ├─────┼──────────────────────────────────────┤
# │ 1   │ {Acne Vulgaris}                      │
# │ 2   │ {HIV Infections}                     │
# │ 3   │ {Acquired Immunodeficiency Syndrome} │
# │ 4   │ {Acquired Immunodeficiency Syndrome} │
# │ 5   │ {Acute Disease}                      │
# │ 6   │ {Acute Disease}                      │
#
# │ Row │ rhs                                │ supp        │ conf     │ lift     │
# ├─────┼────────────────────────────────────┼─────────────┼──────────┼──────────┤
# │ 1   │ Depression                         │ 0.000996133 │ 0.515152 │ 3.07505  │
# │ 2   │ Acquired Immunodeficiency Syndrome │ 0.00158209  │ 0.2      │ 20.4383  │
# │ 3   │ HIV Infections                     │ 0.00158209  │ 0.161677 │ 20.4383  │
# │ 4   │ Substance-Related Disorders        │ 0.00123052  │ 0.125749 │ 1.28813  │
# │ 5   │ Chronic Disease                    │ 0.0014063   │ 0.102564 │ 5.10309  │
# │ 6   │ Mental Disorders                   │ 0.00181648  │ 0.132479 │ 0.617221 │
# Found 476 rules

# %% [markdown]
# ## Frequent Item Sets

# %%
supp_int = round(Int, 0.001 * size(mh_occ, 1))
@time root = frequent_item_tree(mh_occ, supp_int, 9);

supp_lkup = gen_support_dict(root, size(mh_occ, 1))
item_lkup = mesh_frequencies.dicts[2]
item_lkup_t = Dict(zip(values(item_lkup), keys(item_lkup)))
freq = ARules.suppdict_to_datatable(supp_lkup, item_lkup_t);
# Out:
#   0.034929 seconds (68.66 k allocations: 34.563 MiB, 26.16% gc time)

# %%
println(head(freq))
println("Found ", size(freq, 1), " frequent itemsets")
# Out:
# 6×2 DataTables.DataTable
# │ Row │ itemset                                                │ supp │
# ├─────┼────────────────────────────────────────────────────────┼──────┤
# │ 1   │ {Alcoholism,Schizophrenia,Substance-Related Disorders} │ 33   │
# │ 2   │ {Hypertension}                                         │ 57   │
# │ 3   │ {Depression,Substance-Related Disorders}               │ 236  │
# │ 4   │ {Adjustment Disorders,Schizophrenia}                   │ 19   │
# │ 5   │ {Alcoholism,Depressive Disorder, Major}                │ 41   │
# │ 6   │ {Child Abuse,Substance-Related Disorders}              │ 31   │
# Found 518 frequent itemsets

# %% [markdown]
# ## Visualization of Frequent Item Sets
#
# * Basic visualization of frequent item sets using Sankey diagram (experimental - use with caution)
# * Future work inclused better layout for more links as well as the ability to dinamically change the number of of itemsets

# %%
function fill_sankey_data!(node, sources, targets, vals)
    if length(node.item_ids) >1
        push!(sources, node.item_ids[end-1]-1)
        push!(targets, node.item_ids[end]-1)
        push!(vals, node.supp)
    end
    if has_children(node)     
        for nd in node.children
            fill_sankey_data!(nd,  sources, targets, vals)
        end
    end
end
# Out:
# fill_sankey_data! (generic function with 1 method)

# %%
sources = []
targets = []
vals = []
fill_sankey_data!(root, sources, targets, vals);

# %%
# size(sources)
topn_links = 50
freq_vals_perm = sortperm(vals, rev=true)
s = sources[freq_vals_perm[1:topn_links]]
t = targets[freq_vals_perm[1:topn_links]]
v = vals[freq_vals_perm[1:topn_links]]
l = mesh_names

println("Found, ", length(sources), "links, showing ", topn_links)
# Out:
# Found, 358links, showing 50

# %%
pad = 1e-7
trace=sankey(orientation="h",
             node = attr(domain=attr(x=[0,1], y=[0,1]), pad=pad, thickness=pad, line = attr(color="black", width= 0.5),
                         label=l), 
             link = attr(source=s, target=t, value = v))

layout = Layout(width=900, height=1100)
    

plot([trace], layout)
# Out:
# <div id="de4f33e1-c39c-4383-9ad7-2df78c870cb7" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('de4f33e1-c39c-4383-9ad7-2df78c870cb7', [{"link":{"value":[415,307,298,295,290,236,232,209,205,201,199,197,181,180,179,178,175,172,166,161,161,147,143,137,132,125,125,123,119,111,105,99,93,91,91,91,91,91,90,85,83,83,82,81,81,76,76,73,73,72],"source":[554,234,237,35,35,234,105,234,554,35,234,554,66,739,234,237,554,554,105,35,554,237,105,234,105,105,148,853,554,237,782,35,105,66,234,237,681,846,237,622,35,234,554,237,681,35,554,35,105,739],"target":[853,554,554,853,554,853,237,237,739,234,846,782,237,782,782,853,927,846,782,237,681,782,234,739,238,739,599,927,853,739,853,782,554,554,681,846,853,853,681,739,681,622,622,927,782,622,565,739,853,853]},"node":{"pad":1.0e-7,"line":{"color":"black","width":0.5},"label":["ACTH Syndrome, Ectopic","AIDS Dementia Complex","AIDS-Related Complex","AIDS-Related Opportunistic Infections","Acidosis, Lactic","Acidosis, Respiratory","Acne Vulgaris","Acquired Immunodeficiency Syndrome","Acute Coronary Syndrome","Acute Disease","Adams-Stokes Syndrome","Adenocarcinoma","Adenoma","Adenoma, Chromophobe","Adenoma, Islet Cell","Adjustment Disorders","Adrenal Cortex Diseases","Adrenal Gland Diseases","Adrenal Gland Neoplasms","Adrenal Hyperplasia, Congenital","Adrenocortical Hyperfunction","Adrenogenital Syndrome","Affective Disorders, Psychotic","Afibrinogenemia","Agammaglobulinemia","Agoraphobia","Agranulocytosis","Agricultural Workers' Diseases","Airway Obstruction","Akathisia, Drug-Induced","Alcohol Amnestic Disorder","Alcohol Withdrawal Delirium","Alcohol-Induced Disorders","Alcohol-Related Disorders","Alcoholic Intoxication","Alcoholism","Alkalosis","Alopecia","Alopecia Areata","Altitude Sickness","Alzheimer Disease","Amblyopia","Amenorrhea","Amnesia","Amnesia, Retrograde","Amphetamine-Related Disorders","Amyloid Neuropathies","Amyloidosis","Amyotrophic Lateral Sclerosis","Anemia","Anemia, Aplastic","Anemia, Hemolytic","Anemia, Hypochromic","Anemia, Iron-Deficiency","Anemia, Pernicious","Anemia, Sickle Cell","Aneurysm","Aneurysm, Dissecting","Angelman Syndrome","Angiofibroma","Anhedonia","Anorexia","Anorexia Nervosa","Anthrax","Antisocial Personality Disorder","Anuria","Anxiety Disorders","Anxiety, Castration","Anxiety, Separation","Aortic Aneurysm","Aortic Diseases","Aortic Rupture","Apathy","Aphasia","Aphasia, Primary Progressive","Appendicitis","Apraxias","Arterial Occlusive Diseases","Arteriosclerosis","Arteriosclerosis Obliterans","Arthritis","Arthritis, Juvenile","Arthritis, Rheumatoid","Asbestosis","Asperger Syndrome","Asphyxia Neonatorum","Asthma","Asymptomatic Diseases","Ataxia Telangiectasia","Attention Deficit Disorder with Hyperactivity","Auditory Perceptual Disorders","Autism Spectrum Disorder","Autistic Disorder","Autoimmune Diseases","Autonomic Nervous System Diseases","Avitaminosis","Bacteremia","Bacterial Infections","Basal Ganglia Diseases","Battered Child Syndrome","Behavior, Addictive","Behcet Syndrome","Bile Reflux","Biliary Tract Neoplasms","Binge-Eating Disorder","Bipolar Disorder","Bladder Exstrophy","Blood Coagulation Disorders","Blood Group Incompatibility","Blood Platelet Disorders","Blood Protein Disorders","Body Dysmorphic Disorders","Bone Diseases","Bone Marrow Diseases","Bone Neoplasms","Borderline Personality Disorder","Brain Abscess","Brain Damage, Chronic","Brain Diseases","Brain Diseases, Metabolic","Brain Infarction","Brain Ischemia","Brain Neoplasms","Breast Diseases","Breast Neoplasms","Bronchial Neoplasms","Bronchiectasis","Bronchitis","Bronchopneumonia","Brugada Syndrome","Bulimia","Bulimia Nervosa","Bullying","Bundle-Branch Block","Burkitt Lymphoma","Burnout, Professional","Carcinoma","Carcinoma, Bronchogenic","Carcinoma, Hepatocellular","Carcinoma, Small Cell","Carcinoma, Squamous Cell","Carcinoma, Transitional Cell","Cardiac Tamponade","Cardiomyopathies","Cardiomyopathy, Alcoholic","Cardiomyopathy, Dilated","Cardiomyopathy, Hypertrophic","Cardiomyopathy, Hypertrophic, Familial","Cardiovascular Diseases","Carotid Artery Diseases","Car ...
